# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-06-17 16:00:23.420771: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750176023.634514      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750176023.695129      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Set paths to your extracted folder
base_path = ("/kaggle/input/binary-clasification")
train_dir = os.path.join("/kaggle/input/binary-clasification/train/train")
val_dir = os.path.join("/kaggle/input/binary-clasification/val/val")

# %%
# Image parameters
img_height, img_width = 150, 150
batch_size = 32

# %%
# Image data generators
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
val_datagen = ImageDataGenerator(rescale=1.0 / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 1926 images belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 422 images belonging to 2 classes.

# %%
# Model definition
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-17 16:30:22.880355: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train model
model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 46s 703ms/step - accuracy: 0.7811 - loss: 0.7944 - val_accuracy: 0.8175 - val_loss: 0.4307
# Epoch 2/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 672ms/step - accuracy: 0.8505 - loss: 0.3403 - val_accuracy: 0.8555 - val_loss: 0.3604
# Epoch 3/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 82s 671ms/step - accuracy: 0.8852 - loss: 0.2708 - val_accuracy: 0.8626 - val_loss: 0.3469
# Epoch 4/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 42s 688ms/step - accuracy: 0.9196 - loss: 0.2012 - val_accuracy: 0.8578 - val_loss: 0.3676
# Epoch 5/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 665ms/step - accuracy: 0.9457 - loss: 0.1582 - val_accuracy: 0.8531 - val_loss: 0.3339
# Epoch 6/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 661ms/step - accuracy: 0.9615 - loss: 0.1066 - val_accuracy: 0.8697 - val_loss: 0.4327
# Epoch 7/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 671ms/step - accuracy: 0.9693 - loss: 0.0801 - val_accuracy: 0.8768 - val_loss: 0.4373
# Epoch 8/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 665ms/step - accuracy: 0.9809 - loss: 0.0574 - val_accuracy: 0.8626 - val_loss: 0.4195
# Epoch 9/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 668ms/step - accuracy: 0.9844 - loss: 0.0414 - val_accuracy: 0.8555 - val_loss: 0.5322
# Epoch 10/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 42s 690ms/step - accuracy: 0.9908 - loss: 0.0313 - val_accuracy: 0.8649 - val_loss: 0.8501

# %%
# Save model
model.save("gender_classifier_model.h5")
